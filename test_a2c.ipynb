# %%
import math
from tensorboardX import SummaryWriter
import tensorflow.contrib.slim as slim

sess = None

# %%
import tensorflow as tf
import collections
gpu_options = tf.GPUOptions(allow_growth=True,per_process_gpu_memory_fraction=0.8)
tf.reset_default_graph()
sess = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
import env_configurations
import games_configurations
env_name = 'AnimalAIRay'#'PongNoFrameskip-v4' #'MountainCar-v0' #'SuperMarioBros-v1'# 'PongNoFrameskip-v4' #SuperMarioBros-v1'
#env_name = 'CartPole-v1'#'CartPole-v1' #'RoboschoolAnt-v1' #'CarRacing-v0' #'LunarLander-v2' #'Acrobot-v1' #

obs_space, action_space = env_configurations.get_obs_and_action_spaces('AnimalAI')
config = games_configurations.animal_ai_ray

observation_shape = obs_space.shape
n_actions = action_space.n
shape =(None, ) + observation_shape
print(shape)
print(n_actions)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (None, 84, 84, 6)
# 9

# %%
def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

# %%
from a2c_discrete import A2CAgent
import tr_helpers
import networks
import ray
ray.init()
# Out:
# 2019-08-25 20:51:43,509	WARNING worker.py:1337 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-08-25 20:51:43,509	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-25_20-51-43_26437/logs.
# 2019-08-25 20:51:43,620	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:23226 to respond...
# WARNING: Not monitoring node memory since `psutil` is not installed. Install this with `pip install psutil` (or ray[debug]) to enable debugging of memory-related crashes.
# 2019-08-25 20:51:43,741	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:11532 to respond...
# 2019-08-25 20:51:43,742	INFO services.py:804 -- Starting Redis shard with 10.0 GB max memory.
# 2019-08-25 20:51:43,764	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-08-25_20-51-43_26437/logs.
# 2019-08-25 20:51:43,774	WARNING services.py:1279 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2019-08-25 20:51:43,775	INFO services.py:1427 -- Starting the Plasma object store with 20.0 GB memory using /dev/shm.
# 2019-08-25 20:51:43,793	WARNING services.py:907 -- Failed to start the reporter. The reporter requires 'pip install psutil'.
# {'node_ip_address': '192.168.3.115',
#  'redis_address': '192.168.3.115:23226',
#  'object_store_address': '/tmp/ray/session_2019-08-25_20-51-43_26437/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-08-25_20-51-43_26437/sockets/raylet',
#  'webui_url': None}

# %%
agent = A2CAgent(sess,'animal84', obs_space, True, action_space, config)


print(model_summary())
#agent.restore('nn/last84_an15')
agent.train()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0825 20:51:44.009755 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/a2c_discrete.py:91: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0825 20:51:44.032057 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:294: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0825 20:51:44.034164 139620787271488 deprecation.py:323] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:243: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0825 20:51:44.039582 139620787271488 deprecation.py:506] From /home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0825 20:51:44.577735 139620787271488 deprecation.py:323] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:244: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0825 20:51:44.728240 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:206: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# shapes of layer_1 [None, 42, 42, 16]
# shapes of layer_2 [None, 21, 21, 32]
# W0825 20:51:45.245560 139620787271488 deprecation.py:323] From /home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# shapes of layer_3 [None, 11, 11, 64]
# shapes of layer_4 [None, 6, 6, 128]
# W0825 20:51:45.619518 139620787271488 deprecation.py:323] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:300: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0825 20:51:45.945208 139620787271488 deprecation.py:323] From /home/trrrrr/Documents/github/ml/rl_animal/networks.py:145: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0825 20:51:46.978421 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/models.py:53: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0825 20:51:46.981901 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/models.py:54: The name tf.log is deprecated. Please use tf.math.log instead.
# 0
# (pid=26801) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26801) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26801) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# 1
# 2
# 3
# (pid=26814) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26814) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26814) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26814) Preloaded 'ScreenSelector.so'
# (pid=26814) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26814) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26814) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26801) Preloaded 'ScreenSelector.so'
# (pid=26801) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26801) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26801) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# 4
# 5
# (pid=26799) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26799) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26799) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# 6
# 7
# (pid=26799) Preloaded 'ScreenSelector.so'
# (pid=26799) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26799) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26799) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# shapes of layer_1 [None, 42, 42, 16]
# shapes of layer_2 [None, 21, 21, 32]
# shapes of layer_3 [None, 11, 11, 64]
# shapes of layer_4 [None, 6, 6, 128]
# 0
# W0825 20:51:47.230460 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/a2c_discrete.py:185: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0825 20:51:47.249720 139620787271488 deprecation.py:323] From /home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# (pid=26798) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26798) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26798) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26798) Preloaded 'ScreenSelector.so'
# (pid=26798) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26798) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26798) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26794) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26794) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26794) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26794) Preloaded 'ScreenSelector.so'
# (pid=26794) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26794) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26794) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26793) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26793) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26793) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26793) Preloaded 'ScreenSelector.so'
# (pid=26788) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26788) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26788) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26808) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26808) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26808) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26793) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26793) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26793) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26788) Preloaded 'ScreenSelector.so'
# (pid=26788) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26788) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26788) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26808) Preloaded 'ScreenSelector.so'
# (pid=26808) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26808) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26808) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26796) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26796) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26796) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26796) Preloaded 'ScreenSelector.so'
# (pid=26796) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26796) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26796) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26785) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26785) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26785) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26785) Preloaded 'ScreenSelector.so'
# (pid=26785) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26785) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26785) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26804) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26804) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26804) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26804) Preloaded 'ScreenSelector.so'
# (pid=26804) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26804) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26804) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26812) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26812) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26812) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26812) Preloaded 'ScreenSelector.so'
# (pid=26812) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26812) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26812) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26789) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26789) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26789) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26789) Preloaded 'ScreenSelector.so'
# (pid=26789) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26789) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26789) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26813) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26813) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26813) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26813) Preloaded 'ScreenSelector.so'
# (pid=26813) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26813) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26813) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26800) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26800) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26800) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26800) Preloaded 'ScreenSelector.so'
# (pid=26800) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26800) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26800) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26803) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26803) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26803) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26803) Preloaded 'ScreenSelector.so'
# (pid=26803) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26792) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26792) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26792) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26792) Preloaded 'ScreenSelector.so'
# (pid=26792) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26791) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26791) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26791) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26791) Preloaded 'ScreenSelector.so'
# (pid=26791) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26803) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26803) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26792) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26792) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26791) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26791) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26797) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26797) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26797) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26797) Preloaded 'ScreenSelector.so'
# (pid=26797) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26795) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26795) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26795) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26795) Preloaded 'ScreenSelector.so'
# (pid=26795) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26795) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26795) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26797) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26797) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26787) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26787) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26787) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26811) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26811) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26811) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26811) Preloaded 'ScreenSelector.so'
# (pid=26811) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26787) Preloaded 'ScreenSelector.so'
# (pid=26787) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26787) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26787) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26790) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26790) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26790) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26790) Preloaded 'ScreenSelector.so'
# (pid=26790) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26790) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26790) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26811) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26811) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# (pid=26807) Found path: /home/trrrrr/Documents/github/ml/rl_animal/AnimalAI.x86_64
# (pid=26807) Mono path[0] = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/Managed'
# (pid=26807) Mono config path = '/home/trrrrr/Documents/github/ml/rl_animal/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=26807) Preloaded 'ScreenSelector.so'
# (pid=26807) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=26807) Display 0 'U28H75x 27"': 3840x2160 (primary device).
# (pid=26807) Logging to /home/trrrrr/.config/unity3d/Unity Technologies/Unity Environment/Player.log
# W0825 20:51:49.287325 139620787271488 deprecation_wrapper.py:119] From /home/trrrrr/Documents/github/ml/rl_animal/a2c_discrete.py:193: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# ---------
# Variables: name (type shape) [size]
# ---------
# agent/layer_1/kernel:0 (float32_ref 3x3x6x16) [864, bytes: 3456]
# agent/layer_1/bias:0 (float32_ref 16) [16, bytes: 64]
# agent/rb11/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb11/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb11/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb11/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb11/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb11/kernel:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# agent/res2/rb11/kernel:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# agent/rb21/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb21/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb21/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb21/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb21/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb21/kernel:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# agent/res2/rb21/kernel:0 (float32_ref 3x3x16x16) [2304, bytes: 9216]
# agent/layer_2/kernel:0 (float32_ref 3x3x16x32) [4608, bytes: 18432]
# agent/layer_2/bias:0 (float32_ref 32) [32, bytes: 128]
# agent/rb12/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb12/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb12/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb12/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb12/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb12/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# agent/res2/rb12/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# agent/rb22/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb22/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb22/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb22/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb22/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb22/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# agent/res2/rb22/kernel:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# agent/layer_3/kernel:0 (float32_ref 3x3x32x64) [18432, bytes: 73728]
# agent/layer_3/bias:0 (float32_ref 64) [64, bytes: 256]
# agent/rb13/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb13/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb13/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb13/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb13/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb13/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# agent/res2/rb13/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# agent/rb23/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb23/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb23/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb23/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb23/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb23/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# agent/res2/rb23/kernel:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# agent/layer_4/kernel:0 (float32_ref 3x3x64x128) [73728, bytes: 294912]
# agent/layer_4/bias:0 (float32_ref 128) [128, bytes: 512]
# agent/rb14/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb14/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb14/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb14/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb14/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb14/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# agent/res2/rb14/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# agent/rb24/bias0:0 (float32_ref ) [1, bytes: 4]
# agent/rb24/bias1:0 (float32_ref ) [1, bytes: 4]
# agent/rb24/bias2:0 (float32_ref ) [1, bytes: 4]
# agent/rb24/bias3:0 (float32_ref ) [1, bytes: 4]
# agent/rb24/multiplier:0 (float32_ref ) [1, bytes: 4]
# agent/res1/rb24/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# agent/res2/rb24/kernel:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# agent/dense/kernel:0 (float32_ref 6x32) [192, bytes: 768]
# agent/dense/bias:0 (float32_ref 32) [32, bytes: 128]
# agent/dense_1/kernel:0 (float32_ref 4608x512) [2359296, bytes: 9437184]
# agent/dense_1/bias:0 (float32_ref 512) [512, bytes: 2048]
# agent/lstm_ac/lnlstm/wx:0 (float32_ref 544x1024) [557056, bytes: 2228224]
# agent/lstm_ac/lnlstm/gx:0 (float32_ref 1024) [1024, bytes: 4096]
# agent/lstm_ac/lnlstm/bx:0 (float32_ref 1024) [1024, bytes: 4096]
# agent/lstm_ac/lnlstm/wh:0 (float32_ref 256x1024) [262144, bytes: 1048576]
# agent/lstm_ac/lnlstm/gh:0 (float32_ref 1024) [1024, bytes: 4096]
# agent/lstm_ac/lnlstm/bh:0 (float32_ref 1024) [1024, bytes: 4096]
# agent/lstm_ac/lnlstm/b:0 (float32_ref 1024) [1024, bytes: 4096]
# agent/lstm_ac/lnlstm/gc:0 (float32_ref 256) [256, bytes: 1024]
# agent/lstm_ac/lnlstm/bc:0 (float32_ref 256) [256, bytes: 1024]
# agent/dense_2/kernel:0 (float32_ref 256x1) [256, bytes: 1024]
# agent/dense_2/bias:0 (float32_ref 1) [1, bytes: 4]
# agent/dense_3/kernel:0 (float32_ref 256x9) [2304, bytes: 9216]
# agent/dense_3/bias:0 (float32_ref 9) [9, bytes: 36]
# Total size of variables: 4068706
# Total bytes of variables: 16274824
# None
# (pid=26801) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26814) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26799) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26794) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26798) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26788) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26808) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26804) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26813) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26796) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26785) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26793) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26800) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26789) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26792) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26812) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26803) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26791) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26797) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26811) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26795) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26787) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# (pid=26790) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# max epochs 12000
# (pid=26807) WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Frames per seconds:  196.21346530755054
# saving next best rewards:  4.02069
# Frames per seconds:  582.0894649181472
# Frames per seconds:  611.4916451144079
# Frames per seconds:  627.7254936731998
# Frames per seconds:  620.110278344766
# Frames per seconds:  625.9657672576942
# Frames per seconds:  599.047332584871
# Frames per seconds:  609.7295254247555
# Frames per seconds:  625.0136736667438
# Frames per seconds:  623.7023353219674
# Frames per seconds:  605.5689782392054
# Frames per seconds:  621.7687749541813
# Frames per seconds:  616.5574713457698
# Frames per seconds:  611.7086769008499
# Frames per seconds:  621.4275187659517
# Frames per seconds:  620.2598924624347
# Frames per seconds:  621.700613724745
# Frames per seconds:  623.0739150694221
# Frames per seconds:  611.6927629714984
# Frames per seconds:  614.9477535264909
# Frames per seconds:  619.2460091609698
# Frames per seconds:  617.8263456010237
# Frames per seconds:  610.9168900153468
# Frames per seconds:  607.1167482381466
# Frames per seconds:  611.3897432646496
# Frames per seconds:  620.0132409082318
# Frames per seconds:  620.983308072912
# Frames per seconds:  600.7162348749829
# Frames per seconds:  623.0547530276291
# Frames per seconds:  611.6350383673962
# Frames per seconds:  623.2207426468099
# Frames per seconds:  607.973516028446
# Frames per seconds:  612.0953958294538
# Frames per seconds:  615.8345526488305
# Frames per seconds:  621.5631367271791
# Frames per seconds:  607.7936431234973
# Frames per seconds:  587.1391214527367
# Frames per seconds:  609.8531574115638
# Frames per seconds:  613.3089331779954
# Frames per seconds:  605.2755195685163
# Frames per seconds:  613.7712300726471
# Frames per seconds:  615.2091893328933
# Frames per seconds:  617.2461313678393
# Frames per seconds:  604.2445861898977
# Frames per seconds:  613.1368600415594
# Frames per seconds:  613.1665048357958
# Frames per seconds:  622.115091926956
# Frames per seconds:  598.9897422051247
# Frames per seconds:  610.4218631325696
# Frames per seconds:  619.023478007372
# Frames per seconds:  615.7275497861448
# Frames per seconds:  606.603525812742
# Frames per seconds:  612.6242487510168
# Frames per seconds:  617.0180617909625
# Frames per seconds:  623.1708279737493
# Frames per seconds:  612.1209851018547
# Frames per seconds:  618.7397746531141
# Frames per seconds:  618.9839865197376
# Frames per seconds:  616.6371397084033
# Frames per seconds:  615.5524702163016
# Frames per seconds:  604.0544522316571
# Frames per seconds:  613.7832759289563
# Frames per seconds:  609.6630549986978
# Frames per seconds:  617.1017504845854
# Frames per seconds:  602.1229792626987
# Frames per seconds:  614.4234383941038
# Frames per seconds:  621.0649625883235
# Frames per seconds:  619.5131386827622
# Frames per seconds:  607.2419556912176
# Frames per seconds:  560.9558310855747
# Frames per seconds:  570.4485600679602
# Frames per seconds:  531.331953495461
# Frames per seconds:  519.5836705041012
# Frames per seconds:  558.0022720414524
# Frames per seconds:  512.8553490921695
# Frames per seconds:  481.4005686734629
# Frames per seconds:  603.0917987128702
# Frames per seconds:  568.6660747963334
# Frames per seconds:  568.6045419514638
# Frames per seconds:  545.9792101737231
# Frames per seconds:  552.3419170392842
# Frames per seconds:  612.5481764608566
# Frames per seconds:  596.300837428411
# Frames per seconds:  544.7962445684859
# Frames per seconds:  581.4859024359864
# Frames per seconds:  568.1786944199268
# Frames per seconds:  608.3294455977953
# Frames per seconds:  589.4116564693328
# Frames per seconds:  613.060310368368
# Frames per seconds:  600.1035198330484
# Frames per seconds:  496.39900474420057
# Frames per seconds:  596.3249023102686
# Frames per seconds:  561.9825398088171
# Frames per seconds:  567.5904190536335
# Frames per seconds:  556.1047206032649
# Frames per seconds:  589.1168368633672
# Frames per seconds:  594.6055226329305
# Frames per seconds:  601.4692059425703
# Frames per seconds:  588.0512680553879
# Frames per seconds:  589.4447679871001
# Frames per seconds:  579.6821800426931
# Frames per seconds:  614.7813302776457
# Frames per seconds:  599.2462549265533
# Frames per seconds:  600.0291838535085
# Frames per seconds:  602.2553683166673
# Frames per seconds:  504.25731384134053
# Frames per seconds:  551.9273994696316
# Frames per seconds:  598.5218552024093
# Frames per seconds:  606.9222869778403
# Frames per seconds:  595.5096560650197
# Frames per seconds:  589.3344466663129
# Frames per seconds:  608.6194341010105
# Frames per seconds:  596.9261607140376
# Frames per seconds:  608.9361739291858
# Frames per seconds:  610.3245960648281
# Frames per seconds:  602.7203165585114
# Frames per seconds:  610.2199616048665
# Frames per seconds:  590.9466688240856
# Frames per seconds:  562.3102984958686
# Frames per seconds:  589.9443725608808
# Frames per seconds:  501.89142204353516
# Frames per seconds:  585.0883341624985
# Frames per seconds:  552.155969629262
# Frames per seconds:  556.8502343672344
# Frames per seconds:  575.9565729460253
# Frames per seconds:  604.5367054398865
# Frames per seconds:  557.5932132448286
# Frames per seconds:  547.7700757879787
# Frames per seconds:  529.0065246687659
# Frames per seconds:  554.2722905622003
# Exception in thread ray_listen_error_messages:
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/ray/worker.py", line 1650, in listen_error_messages_raylet
#     msg = worker.error_message_pubsub_client.get_message()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
#
# Exception in thread ray_import_thread:
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/ray/import_thread.py", line 70, in _run
#     msg = import_pubsub_client.get_message()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
#
# Exception in thread ray_print_logs:
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/ray/worker.py", line 1547, in print_logs
#     msg = pubsub_client.get_message()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/home/trrrrr/anaconda3/envs/rl/lib/python3.6/site-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-96c17d6b4c08> in <module>
#       4 print(model_summary())
#       5 #agent.restore('nn/last84_an15')
# ----> 6 agent.train()
#
# ~/Documents/github/ml/rl_animal/a2c_discrete.py in train(self)
#     325             epoch_num = self.update_epoch()
#     326             frame += batch_size
# --> 327             obses, vels, returns, dones, actions, values, neglogpacs, lstm_states, _ = self.play_steps()
#     328             advantages = returns - values
#     329             if self.normalize_advantage:
#
# ~/Documents/github/ml/rl_animal/a2c_discrete.py in play_steps(self)
#     236                 mb_states.append(self.states)
#     237
# --> 238             actions, values, neglogpacs, self.states = self.get_action_values(self.obs)
#     239             actions = np.squeeze(actions)
#     240             values = np.squeeze(values)
#
# ~/Documents/github/ml/rl_animal/a2c_discrete.py in get_action_values(self, obs)
#     216         if self.network.is_rnn():
#     217             run_ops.append(self.target_lstm_state)
# --> 218             return self.sess.run(run_ops, {self.target_obs_ph : obs[0], self.target_vels_ph : obs[1], self.target_states_ph : self.states, self.target_masks_ph : self.dones})
#     219         else:
#     220             return (*self.sess.run(run_ops, {self.target_obs_ph : obs[0], self.target_vels_ph : obs[1]}), None)
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/rl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#agent.save('nn/last84_an15')
ray.shutdown()

# %%
gym.envs.registry.all()
